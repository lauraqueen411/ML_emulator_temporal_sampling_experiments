# %%
import xarray as xr
import os

# %%
'''
rename continuation training files

'''

direc = '/nesi/project/niwa00018/queenle/ML_emulator_temporal_sampling_experiments/training/continuation_training/emulators'
emulator = 'pr_ACCESS-CM2_140_cont'

continuation_start = 200

# %%
path = f'{direc}/{emulator}'
for filename in os.listdir(f'{direc}/{emulator}'):
    
    filetype = filename.split('.')[-1]
    
    if filetype == 'png':
        continue
        
        im_n = filename.split('_')[2].split('.')[0]
        epoch = filename.split('_')[1]
        new_epoch = int(epoch) + continuation_start
        
        new_filename = f'epoch_{new_epoch}_{im_n}.h5'
                        
        #os.rename(f'{path}/{filename}', f'{path}/{new_filename}')
        
    elif filetype == 'h5':
        continue
        
        if filename in [f'discriminator_epoch_{continuation_start}.h5',f'generator_epoch_{continuation_start}.h5',f'unet_epoch_{continuation_start}.h5']:
            continue
            
        #model_type = filename.split('_')[0]
        #epoch = filename.split('_')[2].split('.')[0]
        #new_epoch = int(epoch) + continuation_start
        
        #new_filename = f'{model_type}_epoch_{new_epoch}.h5'
                
        #os.rename(f'{path}/{filename}', f'{path}/{new_filename}')
        
    elif filetype == 'json':
        continue
# Out:
# epoch_246_3.png
# epoch_231_5.png
# epoch_213_0.png
# epoch_204_4.png
# epoch_201_7.png
# epoch_225_2.png
# epoch_243_7.png
# epoch_237_1.png
# epoch_225_7.png
# epoch_207_6.png
# epoch_228_4.png
# epoch_240_4.png
# epoch_207_2.png
# epoch_234_1.png
# epoch_231_4.png
# epoch_225_1.png
# epoch_222_4.png
# epoch_237_6.png
# epoch_219_6.png
# epoch_201_4.png
# epoch_237_3.png
# epoch_222_0.png
# epoch_225_6.png
# epoch_240_0.png
# epoch_237_2.png
# epoch_225_0.png
# epoch_237_0.png
# epoch_219_7.png
# epoch_216_6.png
# epoch_204_7.png
# epoch_210_3.png
# epoch_228_2.png
# epoch_234_0.png
# epoch_210_4.png
# epoch_216_5.png
# epoch_234_7.png
# epoch_237_7.png
# epoch_201_6.png
# epoch_234_4.png
# epoch_249_6.png
# epoch_234_2.png
# epoch_219_2.png
# epoch_210_6.png
# epoch_201_2.png
# epoch_246_0.png
# epoch_210_0.png
# epoch_240_2.png
# epoch_213_3.png
# epoch_207_7.png
# epoch_207_4.png
# epoch_216_3.png
# epoch_207_1.png
# epoch_222_3.png
# epoch_210_1.png
# epoch_210_2.png
# ...

# %%
lst.sort()

# %%
lst
# Out:
# [205,
#  205,
#  205,
#  210,
#  210,
#  210,
#  215,
#  215,
#  215,
#  220,
#  220,
#  220,
#  225,
#  225,
#  225,
#  230,
#  230,
#  230,
#  235,
#  235,
#  235,
#  240,
#  240,
#  240,
#  245,
#  245,
#  245,
#  250,
#  250,
#  250]
